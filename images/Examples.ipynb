# %% [markdown]
# # LOEW - Schramm-Loewner Evolutions in Python

# %% [markdown]
# `loew` is a package for simulation of Schramm-Loewner Evolutions (SLE).
#
# [SLE](https://en.wikipedia.org/wiki/Schramm%E2%80%93Loewner_evolution) is a
# nifty mathematical tool to analyze families of random fractals related to
# [critical phenomena](https://en.wikipedia.org/wiki/Critical_phenomena).
# In the last few years some work in the area has moved to numerics, so I hope
# this package will be of some help to those involved. But even if yours is a
# pure mathematics no-computers-allowed type of work, maybe you can use it to make some
# sweet figures for your paper.

# %% [markdown]
# You can start right away by importing it the traditional way

# %%
# %pylab inline --no-import-all
import numpy as np
import loew
plt.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-45d30c2e936e> in <module>
#       1 get_ipython().run_line_magic('pylab', 'inline --no-import-all')
#       2 import numpy as np
# ----> 3 import loew
#       4 plt.style.use('ggplot')
#
# ModuleNotFoundError: No module named 'loew'

# %%
print(dir(loew.chordal))
print(dir(loew))
import inspect
print(inspect.getsource(loew.chordal))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'drive', 'ne', 'np', 'trace', 'vslit_unzip', 'vslit_zip']
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'chordal', 'dipolar', 'loew', 'misc', 'radial']
# import numpy as np
# import numexpr as ne
#
#
# def vslit_zip(z, dt, du):
#     '''
#     Vertical slit discretication of chordal Loewner chains. This function is
#     the inverse of the solution of Loewner's Equation with driving function
#
#     U(t) = du, for 0 <= t <= dt
#
#     It maps the origin to the point w = du + 2j * dt**0.5
#
#     Parameters
#     ----------
#     z : complex or ndarray of complexes
#         Input array.
#
#     dt: float
#     du: float
#         Vertical slit parameters.
#
#     Returns
#     -------
#     w : complex or ndarray of complxes
#         Same shape as input array.
#
#     '''
#     return ne.evaluate("1j * sqrt(4 * dt - z ** 2) + du")
#
#
# def vslit_unzip(z, x, y):
#     '''
#     Vertical slit discretication of chordal Loewner chains. This function is
#     the solution of Loewner's Equation with driving function
#
#     U(t) = du, for 0 <= t <= dt
#
#     Parameters
#     ----------
#     z: complex or ndarray of complex
#         Input Array.
#
#     x: float
#     y: float
#         Vertical slit parameters.
#
#     Returns
#     -------
#     w: complex or ndarray of complex
#         Same shape as input array.
#     '''
#     return ne.evaluate("1j * sqrt(-(z - x) ** 2 - y * y)")
#
#
# def trace(t, u):
#     '''
#     Compute the discretized Loewner trace of a driving function u(t) sampled at
#     discreet time instants. The trace is defined as a curve z(t) such that
#     z(t)= f(t, u(t)) where f(t, w) is the inverse of g(t, w), which is the
#     solution of the Loewner Equation in the upper half-plane
#
#     dg          2
#     -- = ----------------
#     dt    g(t, w) - u(t)
#
#     It makes use of the zipper algorithm with a vertical slit discretization
#     scheme.
#
#     Reference
#     ---------
#     Kennedy, Tom. "Numerical computations for the Schramm-Loewner evolution."
#     Journal of Statistical Physics 137.5-6 (2009): 839-856.
#
#     Parameters
#     ----------
#     t: 1d ndarray of floats
#         Time instants where the driving is sampled.
#
#     u: 1d ndarray of floats
#         Sampled values of the driving function.
#
#     Returns
#     -------
#     z: 1d ndarrays of complex
#         Points of the trace at each time instant.
#     '''
#     n = len(t)
#     z = np.zeros(n, dtype=np.complex128)
#     for i in range(n - 1, 0, -1):
#         dt = t[i] - t[i - 1]
#         du = u[i] - u[i - 1]
#         z[i:] = vslit_zip(z[i:], dt, du)
#     return z
#
#
# def drive(z, destroy=False):
#     '''
#     Compute the driving function u(t) of a Loewner trace z.
#     The drive is obtained by inverting the zipper algorithm.
#     Because of the choice of capacity a(t) = 2t, the time
#     is obtained directly from the trace.
#
#     Reference
#     ---------
#     Kennedy, Tom. "Numerical computations for the Schramm-Loewner evolution."
#     Journal of Statistical Physics 137.5-6 (2009): 839-856.
#
#     Parameters
#     ----------
#     z: 1d ndarrays of complex
#         Points of the discretized trace.
#
#     destroy: bool, optional
#         If set to False, the routine make a copy of z before performing the
#         algorithm. Otherwise it destroys the information on the trace, but
#         saves memory. Default if False.
#
#     Returns
#     -------
#     t: 1d ndarray of floats
#         Time instants where of each trace point. Same shape as z.
#
#     u: 1d ndarray of floats
#         Values of the driving function at each point of the trace.
#         Same shape as z.
#     '''
#     if not destroy:
#         z = np.copy(z)
#     for i, w in enumerate(z[1:], start=1):
#         z[i + 1:] = vslit_unzip(z[i + 1:], w.real, w.imag)
#     u = np.cumsum(z.real)
#     t = np.cumsum(z.imag ** 2 * 0.25)
#     return t, u

# %% [markdown]
# Simulating chordal (i.e. upper half-plane contained)
# Loewner evolutions is as simple as defining a drive and calling
# a function

# %%
# define driving function U(t)
t = np.linspace(0.0, 10.0, 1000)
U = t

# compute a trace in the upper half-plane
zchr = loew.chordal.trace(t, U)  # returns a complex ndarray

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10, 5))

axs[0].set_title('Driving Function')
axs[0].plot(t, U, lw=2)

axs[1].set_title('Chordal')
axs[1].plot(zchr.real, zchr.imag, lw=2)

axs[0].set_xlabel('$t$', fontsize='xx-large')
axs[0].set_ylabel('$U_t$', fontsize='xx-large')
axs[1].set_aspect('equal')
axs[1].set_xlabel('$Re$', fontsize='xx-large')
axs[1].set_ylabel('$Im$', fontsize='xx-large')
fig.tight_layout()

# %% [markdown]
# The package also contains routines for simulating radial and dipolar SLE.
# The radial function is

# %%
# simulate Loewner traces inside de unit disk
zrad = loew.radial.trace(t, U)

# simulate Loewner traces inside the infinite strip of width=pi
zdip = loew.dipolar.trace(t, U, width=1.0)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10, 5))

axs[0].set_title('Radial')
axs[0].plot(zrad.real, zrad.imag, lw=2)

axs[1].set_title('Dipolar')
axs[1].plot(zdip.real, zdip.imag, lw=2)

for ax in axs:
    ax.set_aspect('equal')
    ax.set_xlabel('$Re$', fontsize='xx-large')
    ax.set_ylabel('$Im$', fontsize='xx-large')
a = np.linspace(0.0, 2*np.pi, 100)
axs[0].plot(np.cos(a), np.sin(a), 'k-', lw=2)
axs[1].hlines(np.pi, *ax.get_xlim(), lw=2)
    
fig.tight_layout()

# %% [markdown]
# The algorithm used is the [zipper algorithm](http://arxiv.org/abs/0909.2438), which is $O(N^2)$, so keep that in mind when trying to simulate traces with too many points.

# %% [markdown]
# Of course the "Schramm" part Schramm-Loewner Evolution happen when we use a Brownian motion
# as a drive. We also provide some functions to help you with that.

# %%
np.random.seed(312)
B = loew.misc.brownian_motion(t, kappa=5)
sle = loew.chordal.trace(t, B)
fig, axs = plt.subplots(ncols=2, figsize=(10, 5))

axs[0].set_title('Driving Function')
axs[0].plot(t, B, lw=2)

axs[1].set_title('Chordal SLE')
axs[1].plot(sle.real, sle.imag, lw=2)

axs[0].set_xlabel('$t$', fontsize='xx-large')
axs[0].set_ylabel('$U_t$', fontsize='xx-large')
axs[1].set_aspect('equal')
axs[1].set_xlabel('$Re$', fontsize='xx-large')
axs[1].set_ylabel('$Im$', fontsize='xx-large')
fig.tight_layout()

# %%
# After computing asle, color the trace itself by arc length
asle = loew.chordal.trace(t, fBm)

points = np.array([asle.real, asle.imag]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

from matplotlib.collections import LineCollection
lc = LineCollection(segments, cmap='plasma', linewidth=1.5)
lc.set_array(t[:-1])  # color by time
axs[1].add_collection(lc)
axs[1].autoscale()
plt.colorbar(lc, ax=axs[1], label='$t$')

# %% [markdown]
# And if conformal invariance is too boring for you, we also added a fractional Brownian motion
# routine, just for [fun](http://arxiv.org/abs/1507.05074).

# %%
np.random.seed(123)
t, fBm = loew.misc.fractional_brownian_motion(10000, h=0.75, b=20.0, tf=1.0)
asle = loew.chordal.trace(t, fBm)
fig, axs = plt.subplots(ncols=2, figsize=(10, 5))

axs[0].set_title('Driving Function')
axs[0].plot(t, fBm, lw=2)

axs[1].set_title('Chordal SLE')
axs[1].plot(asle.real, asle.imag, lw=2)

axs[0].set_xlabel('$t$', fontsize='xx-large')
axs[0].set_ylabel('$U_t$', fontsize='xx-large')
axs[1].set_aspect('equal')
axs[1].set_xlabel('$Re$', fontsize='xx-large')
axs[1].set_ylabel('$Im$', fontsize='xx-large')
fig.tight_layout()

# %% [markdown]
# We also added the possibility of doing the inverse operation, computing the driving function out of a trace.
# Currently it is only implemented for the chordal case.

# %%
im = np.linspace(0.0, np.pi, 1000)
re = np.sin(5*im)
z = re + 1j * im
t, u = loew.chordal.drive(z)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10, 5))

axs[0].set_title('Chordal SLE')
axs[0].plot(z.real, z.imag, lw=2)

axs[1].set_title('Driving Function')
axs[1].plot(t, u, lw=2)

axs[0].set_aspect('equal')
axs[0].set_xlabel('$Re$', fontsize='xx-large')
axs[0].set_ylabel('$Im$', fontsize='xx-large')
axs[1].set_xlabel('$t$', fontsize='xx-large')
axs[1].set_ylabel('$U_t$', fontsize='xx-large')

fig.tight_layout()
